# %% [markdown]
# 作業一
# 1.選的data，可根據品酒人的描述來判斷酒的品種，建立modle，其中一種應用是可讓終端消費者評斷酒的味道與標示是否一致。
# 2.data從販售酒的網站上來，該網站上有註明酒的來源及品酒師的描述
# 3.data為csv檔，欄位有country/description/designation/points/price/province/region_1/region_2/taster_name/taster_twitter_handle/title/variety/variety
# 4.由專業品酒師，品味不知名之紅酒，將描述給model來輸出酒的產地，年份是否正確

# %% [markdown]
# 作業二
# 1.提升業績，可分為提高載客率或是提高載運的單價，在此先定義為提高載客率，如何讓車隊的車，將等待時間降至最低即為核心問題。
# 2.需要由每台車蒐集載客點，時間，下客點等資訊
# 3.excel檔條列每次載乘資訊，蒐集六個月到一年的data
# 4.藉由預測載客點即載客時間，在預定的時間前5分左右在到達該地點，持續施行測試一個月後，回饋的等待時間是否降低

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 12.159

# %%
def mean_Squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = MSE = sum(((yp - y)**2) / len(y))
    return mse

MSE = mean_Squared_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 12.159
